# %%
import numpy as np
import matplotlib.pyplot as plt
PSR=np.loadtxt('C:\\Users\\MayHem\\epoch2.txt')                                         #initializing empty array
psr_new=[]                    #initializing emapty array for matrix
for i in range(650):
    m=[0]*1024
    for j in range(10):
        u=PSR[1024*(j+10*i):1024*((j+1)+10*i),3]
        m=m+u
    n=m/10                                        #n is averaged value of cumulative 10 pulses
    psr_new.append(n)                             #psr_new is resultant matrix containing columns of pulses

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-d6d3d37ec8a2> in <module>
# ----> 1 len(psr_new)
#
# NameError: name 'psr_new' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.ndimage import gaussian_filter

PSR=np.loadtxt('C:\\Users\\MayHem\\epoch2.txt')
pulse=[]
output = gaussian_filter(np.mean(psr_new[0:66],axis=0),sigma=2)
#output2= gaussian_filter(np.mean(psr_new[0:66],axis=0),sigma=4)
o=np.roll(output,-200)

#plt.plot(np.mean(psr_new[0:66],axis=0))
plt.plot(o)
#plt.plot(output1)
plt.show()

#output = gaussian_filter(m,sigma=4)

# %%
PSR=np.loadtxt('C:\\Users\\MayHem\\epoch2.txt')
pulse1=[]
#plt.plot(np.mean(psr_new[66:112],axis=0))
output1 = gaussian_filter(np.mean(psr_new[66:112],axis=0),sigma=2)
#plt.plot(output1)
o2=np.roll(output1,-200)
plt.plot(o2)
plt.show()

# %%
PSR=np.loadtxt('C:\\Users\\MayHem\\epoch2.txt')
pulse2=[]
#plt.plot(np.mean(psr_new[111:161],axis=0))
output2 = gaussian_filter(np.mean(psr_new[111:161],axis=0),sigma=2)
#plt.plot(output2)
o3 = np.roll(output2,-200)
plt.plot(o3)
plt.show()

# %%
#plt.plot(np.mean(psr_new[161:281],axis=0))
output3 = gaussian_filter(np.mean(psr_new[161:181],axis=0),sigma=2)
plt.plot(output3)

# %%
#plt.plot(np.mean(psr_new[281:321],axis=0))
output4 = gaussian_filter(np.mean(psr_new[281:321],axis=0),sigma=2)
plt.plot(output4)

# %%
#plt.plot(np.mean(psr_new[321:361],axis=0))
output5 = gaussian_filter(np.mean(psr_new[321:361],axis=0),sigma=2)
plt.plot(output5)

# %%
#plt.plot(np.mean(psr_new[361:411],axis=0))
output6 = gaussian_filter(np.mean(psr_new[361:411],axis=0),sigma=2)
plt.plot(output6)

# %%
#plt.plot(np.mean(psr_new[411:511],axis=0))
output7 = gaussian_filter(np.mean(psr_new[411:511],axis=0),sigma=2)
plt.plot(output7)

# %%
#plt.plot(np.mean(psr_new[511:650],axis=0))
output8 = gaussian_filter(np.mean(psr_new[511:650],axis=0),sigma=2)
plt.plot(output8)

# %%
y=np.mean(psr_new[0:66],axis=0)+np.mean(psr_new[111:161],axis=0)+np.mean(psr_new[281:321],axis=0)+np.mean(psr_new[361:411],axis=0)+np.mean(psr_new[511:650],axis=0)
r=np.divide(y,5)
plt.plot(r)

# %%
x=np.mean(psr_new[66:112],axis=0)+np.mean(psr_new[161:281],axis=0)+np.mean(psr_new[321:361],axis=0)+np.mean(psr_new[411:511],axis=0)
s=x/4
plt.plot(s)

# %%
plt.plot(r)
plt.plot(s)

# %%
import numpy as np
import matplotlib.pyplot as plt
PSR=np.loadtxt('C:\\Users\\MayHem\\output1.txt')                                         #initializing empty array
psr_new=[]                    #initializing emapty array for matrix
for i in range(350):
    m=[0]*512
    for j in range(10):
        u=PSR[512*(j+10*i):512*((j+1)+10*i),3]
        m=m+u
    n=m/10                                        #n is averaged value of cumulative 10 pulses
    psr_new.append(n)

# %%
plt.plot(np.mean(psr_new[0:31],axis=0))

# %%
plt.plot(np.mean(psr_new[31:66],axis=0))

# %%
plt.plot(np.mean(psr_new[66:81],axis=0))

# %%
plt.plot(np.mean(psr_new[81:104],axis=0))

# %%
plt.plot(np.mean(psr_new[104:143],axis=0))

# %%
plt.plot(np.mean(psr_new[143:203],axis=0))

# %%
plt.plot(np.mean(psr_new[203:231],axis=0))

# %%
plt.plot(np.mean(psr_new[231:350],axis=0))

# %%
y=np.mean(psr_new[0:31],axis=0)+np.mean(psr_new[66:204],axis=0)+np.mean(psr_new[231:350],axis=0)
r=np.divide(y,3)
plt.plot(r)

# %%
x=np.mean(psr_new[31:67],axis=0)+np.mean(psr_new[204:231],axis=0)
s=np.divide(x,2)
plt.plot(s)

# %%
plt.plot(r)
plt.plot(s)
plt.xlim(200,300)
# Out:
# (200, 300)

# %%
plt.plot(r)
plt.plot(s)

# %%
import numpy as np
import matplotlib.pyplot as plt
PSR=np.loadtxt('C:\\Users\\MayHem\\epoch2.txt')                                         #initializing empty array
psr_new1=[]                    #initializing emapty array for matrix
for i in range(650):
    m=[0]*1024
    for j in range(10):
        u=PSR[1024*(j+10*i):1024*((j+1)+10*i),4]
        m=m+u
    n=m/10                                        #n is averaged value of cumulative 10 pulses
    psr_new1.append(n)

# %%
y1=np.mean(psr_new1[0:66],axis=0)+np.mean(psr_new1[111:161],axis=0)+np.mean(psr_new1[281:321],axis=0)+np.mean(psr_new1[361:411],axis=0)+np.mean(psr_new1[511:650],axis=0)
r1=np.divide(y1,5)
plt.plot(r1)
x1=np.mean(psr_new1[66:112],axis=0)+np.mean(psr_new1[161:281],axis=0)+np.mean(psr_new1[321:361],axis=0)+np.mean(psr_new1[411:511],axis=0)
s1=x1/4
plt.plot(s1)
plt.xlim(400,600)
plt.legend(["Strong mode","weak mode"])
plt.ylabel('Intesnity')
plt.xlabel('Phase Bins')
plt.axvline(x=470,color='k')
plt.axvline(x=500,color='k')
plt.axvline(x=485,color='k')

# %%
import numpy as np
import matplotlib.pyplot as plt
PSR=np.loadtxt('C:\\Users\\MayHem\\epoch2.txt')                                         #initializing empty array
psr_new2=[]                    #initializing emapty array for matrix
for i in range(650):
    m=[0]*1024
    for j in range(10):
        u=PSR[1024*(j+10*i):1024*((j+1)+10*i),5]
        m=m+u
    n=m/10                                        #n is averaged value of cumulative 10 pulses
    psr_new2.append(n)

# %%
y2=np.mean(psr_new2[0:66],axis=0)+np.mean(psr_new2[111:161],axis=0)+np.mean(psr_new2[281:321],axis=0)+np.mean(psr_new2[361:411],axis=0)+np.mean(psr_new2[511:650],axis=0)
r2=np.divide(y2,5)
plt.plot(r2)
x2=np.mean(psr_new2[66:112],axis=0)+np.mean(psr_new2[161:281],axis=0)+np.mean(psr_new2[321:361],axis=0)+np.mean(psr_new2[411:511],axis=0)
s2=x2/4
plt.plot(s2)
plt.xlim(400,600)
plt.legend(["Strong mode","weak mode"])
plt.ylabel('Intesnity')
plt.xlabel('Phase Bins')
plt.axvline(x=470,color='k')
plt.axvline(x=500,color='k')
plt.axvline(x=485,color='k')

# %%
import numpy as np
import matplotlib.pyplot as plt
PSR=np.loadtxt('C:\\Users\\MayHem\\epoch2.txt')                                         #initializing empty array
psr_new3=[]                    #initializing emapty array for matrix
for i in range(650):
    m=[0]*1024
    for j in range(10):
        u=PSR[1024*(j+10*i):1024*((j+1)+10*i),6]
        m=m+u
    n=m/10                                        #n is averaged value of cumulative 10 pulses
    psr_new3.append(n)

# %%
y3=np.mean(psr_new3[0:66],axis=0)+np.mean(psr_new3[111:161],axis=0)+np.mean(psr_new3[281:321],axis=0)+np.mean(psr_new3[361:411],axis=0)+np.mean(psr_new3[511:650],axis=0)
r3=np.divide(y3,5)
plt.plot(r3)
x3=np.mean(psr_new3[66:112],axis=0)+np.mean(psr_new3[161:281],axis=0)+np.mean(psr_new3[321:361],axis=0)+np.mean(psr_new3[411:511],axis=0)
s3=x3/4
plt.plot(s3)
plt.xlim(400,600)
plt.legend(["Strong mode","weak mode"])
plt.ylabel('Intesnity')
plt.xlabel('Phase Bins')
plt.axvline(x=470,color='k')
plt.axvline(x=500,color='k')
plt.axvline(x=485,color='k')

# %%
import numpy as np
import matplotlib.pyplot as plt


PSR=np.loadtxt('C:\\Users\\MayHem\\pe-epoch2.txt')
c = PSR[0:660 ,5]
PSR_new = []

#for i in range(66):
 #   PSR_new.append(np.mean(c[10*i:10*i+10]))
psr_fft = np.fft.fft(c)

freq = np.fft.fftfreq(len(psr_fft))
plt.plot(np.abs(freq)[1:],(np.abs(psr_fft)[1:])**2)
plt.xlabel('frequency(Hz)',fontsize=15)
plt.ylabel('Power',fontsize=15)
plt.xscale('log')
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


PSR=np.loadtxt('C:\\Users\\MayHem\\pe-epoch2.txt')
c = PSR[660:1120 ,5]
PSR_new = []

#for i in range(46):
#    PSR_new.append(np.mean(c[10*i:10*i+10]))
psr_fft = np.fft.fft(c)

freq = np.fft.fftfreq(len(psr_fft))
plt.plot(np.abs(freq)[1:],(np.abs(psr_fft)[1:])**2)
plt.xlabel('frequency(Hz)',fontsize=15)
plt.ylabel('Power',fontsize=15)
plt.xscale('log')
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


PSR=np.loadtxt('C:\\Users\\MayHem\\pe-epoch2.txt')
c = PSR[1120:1610 ,5]
PSR_new = []

#for i in range(49):
 #   PSR_new.append(np.mean(c[10*i:10*i+10]))
psr_fft = np.fft.fft(c)

freq = np.fft.fftfreq(len(psr_fft))
plt.plot(np.abs(freq)[1:],(np.abs(psr_fft)[1:])**2)
plt.xlabel('frequency(Hz)',fontsize=15)
plt.ylabel('Power',fontsize=15)
plt.xscale('log')
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


PSR=np.loadtxt('C:\\Users\\MayHem\\pe-epoch2.txt')
c = PSR[1610:2810 ,5]
PSR_new = []

#for i in range(120):
#    PSR_new.append(np.mean(c[10*i:10*i+10]))
psr_fft = np.fft.fft(c)

freq = np.fft.fftfreq(len(psr_fft))
plt.plot(np.abs(freq)[1:],(np.abs(psr_fft)[1:])**2)
plt.xlabel('frequency(Hz)',fontsize=15)
plt.ylabel('Power',fontsize=15)
plt.xscale('log')
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


PSR=np.loadtxt('C:\\Users\\MayHem\\pe-epoch2.txt')
c = PSR[2810:3210 ,5]
PSR_new = []

#for i in range(40):
#    PSR_new.append(np.mean(c[10*i:10*i+10]))
psr_fft = np.fft.fft(c)

freq = np.fft.fftfreq(len(psr_fft))
plt.plot(np.abs(freq)[1:],(np.abs(psr_fft)[1:])**2)
plt.xlabel('frequency(Hz)',fontsize=15)
plt.ylabel('Power',fontsize=15)
plt.xscale('log')
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


PSR=np.loadtxt('C:\\Users\\MayHem\\pe-epoch2.txt')
c = PSR[3210:3610 ,5]
PSR_new = []

#for i in range(40):
 #   PSR_new.append(np.mean(c[10*i:10*i+10]))
psr_fft = np.fft.fft(c)

freq = np.fft.fftfreq(len(psr_fft))
plt.plot(np.abs(freq)[1:],(np.abs(psr_fft)[1:])**2)
plt.xlabel('frequency(Hz)',fontsize=15)
plt.ylabel('Power',fontsize=15)
plt.xscale('log')
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


PSR=np.loadtxt('C:\\Users\\MayHem\\pe-epoch2.txt')
c = PSR[3610:4110 ,5]
PSR_new = []

#for i in range(50):
#    PSR_new.append(np.mean(c[10*i:10*i+10]))
psr_fft = np.fft.fft(c)

freq = np.fft.fftfreq(len(psr_fft))
plt.plot(np.abs(freq)[1:],(np.abs(psr_fft)[1:])**2)
plt.xlabel('frequency(Hz)',fontsize=15)
plt.ylabel('Power',fontsize=15)
plt.xscale('log')
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


PSR=np.loadtxt('C:\\Users\\MayHem\\pe-epoch2.txt')
c = PSR[4110:5110 ,5]
PSR_new = []

#for i in range(100):
 #   PSR_new.append(np.mean(c[10*i:10*i+10]))
psr_fft = np.fft.fft(c)

freq = np.fft.fftfreq(len(psr_fft))
plt.plot(np.abs(freq)[1:],(np.abs(psr_fft)[1:])**2)
plt.xlabel('frequency(Hz)',fontsize=15)
plt.ylabel('Power',fontsize=15)
plt.xscale('log')
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


PSR=np.loadtxt('C:\\Users\\MayHem\\pe-epoch2.txt')
c = PSR[5110:6500 ,5]
PSR_new = []

#for i in range(139):
#    PSR_new.append(np.mean(c[10*i:10*i+10]))
psr_fft = np.fft.fft(c)

freq = np.fft.fftfreq(len(psr_fft))
plt.plot(np.abs(freq)[1:],(np.abs(psr_fft)[1:])**2)
plt.xlabel('frequency(Hz)',fontsize=15)
plt.ylabel('Power',fontsize=15)
plt.xscale('log')
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)


plt.show()

# %%
c=60
print(c)
# Out:
# 60

# %%
c=80
print(c)
# Out:
# 80

# %%
import numpy as np
import matplotlib.pyplot as plt
PSR=np.loadtxt('C:\\Users\\MayHem\\epoch2.txt')
pulse=[]                                     #creating empty array
for j in range(0,90):
   pulse.append([PSR[x][-4] for x in range(7680*j,(7680*j)+7680)][0:7680])#intensity values are appended to 'pulse' for every 15*512 bins
       
m=np.mean(pulse,axis=0)                                                   #all appended values are averaged
plt.plot(m)

# %%
import numpy as np
import matplotlib.pyplot as plt


PSR=np.loadtxt('C:\\Users\\MayHem\\PE.txt')
c = PSR[0:310 ,5]
PSR_new = []

#for i in range(139):
#    PSR_new.append(np.mean(c[10*i:10*i+10]))
psr_fft = np.fft.fft(c)

freq = np.fft.fftfreq(len(psr_fft))
plt.plot(np.abs(freq)[1:],(np.abs(psr_fft)[1:])**2)
plt.xlabel('frequency(Hz)',fontsize=15)
plt.ylabel('Power',fontsize=15)
plt.xscale('log')
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


PSR=np.loadtxt('C:\\Users\\MayHem\\PE.txt')
c = PSR[310:660 ,5]
PSR_new = []

#for i in range(139):
#    PSR_new.append(np.mean(c[10*i:10*i+10]))
psr_fft = np.fft.fft(c)

freq = np.fft.fftfreq(len(psr_fft))
plt.plot(np.abs(freq)[1:],(np.abs(psr_fft)[1:])**2)
plt.xlabel('frequency(Hz)',fontsize=15)
plt.ylabel('Power',fontsize=15)
plt.xscale('log')
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


PSR=np.loadtxt('C:\\Users\\MayHem\\PE.txt')
c = PSR[660:2040 ,5]
PSR_new = []

#for i in range(139):
#    PSR_new.append(np.mean(c[10*i:10*i+10]))
psr_fft = np.fft.fft(c)

freq = np.fft.fftfreq(len(psr_fft))
plt.plot(np.abs(freq)[1:],(np.abs(psr_fft)[1:])**2)
plt.xlabel('frequency(Hz)',fontsize=15)
plt.ylabel('Power',fontsize=15)
plt.xscale('log')
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


PSR=np.loadtxt('C:\\Users\\MayHem\\PE.txt')
c = PSR[2040:2310 ,5]
PSR_new = []

#for i in range(139):
#    PSR_new.append(np.mean(c[10*i:10*i+10]))
psr_fft = np.fft.fft(c)

freq = np.fft.fftfreq(len(psr_fft))
plt.plot(np.abs(freq)[1:],(np.abs(psr_fft)[1:])**2)
plt.xlabel('frequency(Hz)',fontsize=15)
plt.ylabel('Power',fontsize=15)
plt.xscale('log')
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


PSR=np.loadtxt('C:\\Users\\MayHem\\PE.txt')
c = PSR[2310:3500 ,5]
PSR_new = []

#for i in range(139):
#    PSR_new.append(np.mean(c[10*i:10*i+10]))
psr_fft = np.fft.fft(c)

freq = np.fft.fftfreq(len(psr_fft))
plt.plot(np.abs(freq)[1:],(np.abs(psr_fft)[1:])**2)
plt.xlabel('frequency(Hz)',fontsize=15)
plt.ylabel('Power',fontsize=15)
plt.xscale('log')
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)


plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
PSR=np.loadtxt('C:\\Users\\MayHem\\epoch2.txt')
pulse=[]                                     #creating empty array
for j in range(0,5):
   pulse.append([PSR[x][-4] for x in range(46080*j,(46080*j)+46080)][0:46080])#intensity values are appended to 'pulse' for every 15*512 bins
       
m=np.mean(pulse,axis=0)                                                   #all appended values are averaged
plt.plot(m)

# %%
import numpy as np
import matplotlib.pyplot as plt
PSR=np.loadtxt('C:\\Users\\MayHem\\epoch2.txt')
pulse=[]                                     #creating empty array
for j in range(0,100):
   pulse.append([PSR[x][-4] for x in range(30720*j,(30720*j)+30720)][0:30720])#intensity values are appended to 'pulse' for every 15*512 bins
       
m=np.mean(pulse,axis=0)                                                   #all appended values are averaged
plt.plot(m)

# %%
import numpy as np
import matplotlib.pyplot as plt
PSR=np.loadtxt('C:\\Users\\MayHem\\epoch2.txt')
pulse=[]                                     #creating empty array
for j in range(0,9):
   pulse.append([PSR[x][-4] for x in range(145408*j,(145408*j)+145408)][0:145408])#intensity values are appended to 'pulse' for every 15*512 bins
       
m=np.mean(pulse,axis=0)                                                   #all appended values are averaged
plt.plot(m)

# %%
import matplotlib.pyplot as plt
import numpy as np



PSR=np.loadtxt('C:\\Users\\MayHem\\PE.txt')
x1 = PSR[:,5]
y1 = PSR[:,6]

plt.hist(x1, density=False, bins=30,histtype=u'step') 
plt.hist(y1, density=False, bins=30,histtype=u'step')# density=False would make counts
plt.ylabel('Number')
plt.xlabel('Energy')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np



PSR1=np.loadtxt('C:\\Users\\MayHem\\pe-epoch2.txt')
x = PSR1[:,5]
y = PSR1[:,6]

plt.hist(x, density=False, bins=30) 
plt.hist(y, density=False, bins=30,color='r')# density=False would make counts
plt.ylabel('Number')
plt.xlabel('Energy')
plt.xlim(-0.2,0.2)
plt.show()

# %%
plt.hist(y, density=False, bins=30,color='r')
plt.ylabel('Number')
plt.xlabel('Energy')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
PSR=np.loadtxt('C:\\Users\\MayHem\\pe-epoch2.txt')

d=[]                    #empty array
for i in range(598):
    u=PSR[10*i:512+(10*i),5]        #selecting every 512 elements and advancing by 10 elements
    psr_fft = np.fft.fft(u)
    freq = np.fft.fftfreq(len(psr_fft))
    d.append(np.abs(psr_fft)[1:]**2)   #appending obtained psr_fft values to empty array                  #array containing 300 rows of data
f=np.transpose(d) 
plt.imshow(f[1:256])

plt.ylim(1,256)
plt.xlim(0,)



plt.yscale('log')
plt.xlabel('Start pulse number',fontsize=15)
plt.ylabel('frequency(Hz)',fontsize=15)
locs_x,labels_x = plt.xticks()
labels_x = [0,1000,2000,300,400,5000,6000]
plt.xticks(locs_x,labels_x)
locs_y,labels_y= plt.yticks()
labels_y = [0.0001,0.001,0.01,0.1,0.5] 
plt.yticks(locs_y,labels_y)
plt.xlabel('starting pulse number',fontsize=15)
plt.ylabel('frequency(Hz)',fontsize=15)
plt.rc('xtick', labelsize=10)    # fontsize of the tick labels
plt.rc('ytick', labelsize=10)
plt.savefig('m29.jpg')
plt.colorbar()
plt.show()
# Out:
# C:\Users\MayHem\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: UserWarning: aspect is not supported for Axes with xscale=linear, yscale=log

# %%
plt.hist(y1, density=False, bins=30,color='r')
plt.ylabel('Number')
plt.xlabel('Energy')
plt.show()
